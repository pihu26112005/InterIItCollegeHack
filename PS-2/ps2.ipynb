# %%
import json

# Load the corpus data
with open('corpus.json', 'r') as f:
    corpus_data = json.load(f)

# Extract relevant metadata and article content
documents = []
for article in corpus_data:
    document = {
        'title': article['title'],
        'author': article['author'],
        'source': article['source'],
        'published_at': article['published_at'],
        'category': article['category'],
        'url': article['url'],
        'content': article['body']
    }
    documents.append(document)

print(f"Loaded {len(documents)} documents.")
# Out:
# Loaded 609 documents.

# %%
# Install the required package
# !pip install sentence-transformers chromadb

from sentence_transformers import SentenceTransformer
import chromadb

# Load the sentence transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Create embeddings for the document content
for document in documents:
    document['embedding'] = model.encode(document['content'])

# Initialize ChromaDB
chroma_client = chromadb.Client()

# Create a collection to store embeddings
collection = chroma_client.get_or_create_collection("documents")

# Add documents and their embeddings to the vector database
for i, doc in enumerate(documents): # Use enumerate to generate unique ids
    print(f"Adding document {i+1}/{len(documents)}")
    # Create a copy of metadata to avoid modifying the original document
    metadata = {'title': doc['title'], 'url': doc['url'],'author': doc['author'],'source': doc['source'], 'category':doc['category'], 'published_at': doc['published_at']}

    # Replace None values with empty strings for metadata fields
    for key in metadata:
        if metadata[key] is None:
            metadata[key] = ""  # Or any other suitable default value

    # Add 'author' only if it's not None (this line is now redundant but harmless)
    #if doc['author'] is not None:
    #    metadata['author'] = doc['author']
    collection.add(
        ids=[str(i)], # Provide unique ids for each document
        documents=[doc['content']],
        metadatas=[metadata],  # Use the modified metadata
        embeddings=[doc['embedding']]
    )
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Adding document 1/609
# Adding document 2/609
# Adding document 3/609
# Adding document 4/609
# Adding document 5/609
# Adding document 6/609
# Adding document 7/609
# Adding document 8/609
# Adding document 9/609
# Adding document 10/609
# Adding document 11/609
# Adding document 12/609
# Adding document 13/609
# Adding document 14/609
# Adding document 15/609
# Adding document 16/609
# Adding document 17/609
# Adding document 18/609
# Adding document 19/609
# Adding document 20/609
# Adding document 21/609
# Adding document 22/609
# Adding document 23/609
# Adding document 24/609
# Adding document 25/609
# Adding document 26/609
# Adding document 27/609
# Adding document 28/609
# Adding document 29/609
# Adding document 30/609
# Adding document 31/609
# Adding document 32/609
# Adding document 33/609
# Adding document 34/609
# Adding document 35/609
# Adding document 36/609
# Adding document 37/609
# Adding document 38/609
# Adding document 39/609
# Adding document 40/609
# Adding document 41/609
# Adding document 42/609
# Adding document 43/609
# Adding document 44/609
# Adding document 45/609
# Adding document 46/609
# Adding document 47/609
# Adding document 48/609
# Adding document 49/609
# Adding document 50/609
# Adding document 51/609
# Adding document 52/609
# Adding document 53/609
# Adding document 54/609
# Adding document 55/609
# Adding document 56/609
# Adding document 57/609
# Adding document 58/609
# Adding document 59/609
# Adding document 60/609
# Adding document 61/609
# Adding document 62/609
# Adding document 63/609
# Adding document 64/609
# Adding document 65/609
# Adding document 66/609
# Adding document 67/609
# Adding document 68/609
# Adding document 69/609
# Adding document 70/609
# Adding document 71/609
# Adding document 72/609
# Adding document 73/609
# Adding document 74/609
# Adding document 75/609
# Adding document 76/609
# Adding document 77/609
# Adding document 78/609
# Adding document 79/609
# Adding document 80/609
# Adding document 81/609
# Adding document 82/609
# Adding document 83/609
# Adding document 84/609
# Adding document 85/609
# Adding document 86/609
# Adding document 87/609
# Adding document 88/609
# Adding document 89/609
# Adding document 90/609
# Adding document 91/609
# Adding document 92/609
# Adding document 93/609
# Adding document 94/609
# Adding document 95/609
# Adding document 96/609
# Adding document 97/609
# Adding document 98/609
# Adding document 99/609
# Adding document 100/609
# Adding document 101/609
# Adding document 102/609
# Adding document 103/609
# Adding document 104/609
# Adding document 105/609
# Adding document 106/609
# Adding document 107/609
# Adding document 108/609
# Adding document 109/609
# Adding document 110/609
# Adding document 111/609
# Adding document 112/609
# Adding document 113/609
# Adding document 114/609
# Adding document 115/609
# Adding document 116/609
# Adding document 117/609
# Adding document 118/609
# Adding document 119/609
# Adding document 120/609
# Adding document 121/609
# Adding document 122/609
# Adding document 123/609
# Adding document 124/609
# Adding document 125/609
# Adding document 126/609
# Adding document 127/609
# Adding document 128/609
# Adding document 129/609
# Adding document 130/609
# Adding document 131/609
# Adding document 132/609
# Adding document 133/609
# Adding document 134/609
# Adding document 135/609
# Adding document 136/609
# Adding document 137/609
# Adding document 138/609
# Adding document 139/609
# Adding document 140/609
# Adding document 141/609
# Adding document 142/609
# Adding document 143/609
# Adding document 144/609
# Adding document 145/609
# Adding document 146/609
# Adding document 147/609
# Adding document 148/609
# Adding document 149/609
# Adding document 150/609
# Adding document 151/609
# Adding document 152/609
# Adding document 153/609
# Adding document 154/609
# Adding document 155/609
# Adding document 156/609
# Adding document 157/609
# Adding document 158/609
# Adding document 159/609
# Adding document 160/609
# Adding document 161/609
# Adding document 162/609
# Adding document 163/609
# Adding document 164/609
# Adding document 165/609
# Adding document 166/609
# Adding document 167/609
# Adding document 168/609
# Adding document 169/609
# Adding document 170/609
# Adding document 171/609
# Adding document 172/609
# Adding document 173/609
# Adding document 174/609
# Adding document 175/609
# Adding document 176/609
# Adding document 177/609
# Adding document 178/609
# Adding document 179/609
# Adding document 180/609
# Adding document 181/609
# Adding document 182/609
# Adding document 183/609
# Adding document 184/609
# Adding document 185/609
# Adding document 186/609
# Adding document 187/609
# Adding document 188/609
# Adding document 189/609
# Adding document 190/609
# Adding document 191/609
# Adding document 192/609
# Adding document 193/609
# Adding document 194/609
# Adding document 195/609
# Adding document 196/609
# Adding document 197/609
# Adding document 198/609
# Adding document 199/609
# Adding document 200/609
# Adding document 201/609
# Adding document 202/609
# Adding document 203/609
# Adding document 204/609
# Adding document 205/609
# Adding document 206/609
# Adding document 207/609
# Adding document 208/609
# Adding document 209/609
# Adding document 210/609
# Adding document 211/609
# Adding document 212/609
# Adding document 213/609
# Adding document 214/609
# Adding document 215/609
# Adding document 216/609
# Adding document 217/609
# Adding document 218/609
# Adding document 219/609
# Adding document 220/609
# Adding document 221/609
# Adding document 222/609
# Adding document 223/609
# Adding document 224/609
# Adding document 225/609
# Adding document 226/609
# Adding document 227/609
# Adding document 228/609
# Adding document 229/609
# Adding document 230/609
# Adding document 231/609
# Adding document 232/609
# Adding document 233/609
# Adding document 234/609
# Adding document 235/609
# Adding document 236/609
# Adding document 237/609
# Adding document 238/609
# Adding document 239/609
# Adding document 240/609
# Adding document 241/609
# Adding document 242/609
# Adding document 243/609
# Adding document 244/609
# Adding document 245/609
# Adding document 246/609
# Adding document 247/609
# Adding document 248/609
# Adding document 249/609
# Adding document 250/609
# Adding document 251/609
# Adding document 252/609
# Adding document 253/609
# Adding document 254/609
# Adding document 255/609
# Adding document 256/609
# Adding document 257/609
# Adding document 258/609
# Adding document 259/609
# Adding document 260/609
# Adding document 261/609
# Adding document 262/609
# Adding document 263/609
# Adding document 264/609
# Adding document 265/609
# Adding document 266/609
# Adding document 267/609
# Adding document 268/609
# Adding document 269/609
# Adding document 270/609
# Adding document 271/609
# Adding document 272/609
# Adding document 273/609
# Adding document 274/609
# Adding document 275/609
# Adding document 276/609
# Adding document 277/609
# Adding document 278/609
# Adding document 279/609
# Adding document 280/609
# Adding document 281/609
# Adding document 282/609
# Adding document 283/609
# Adding document 284/609
# Adding document 285/609
# Adding document 286/609
# Adding document 287/609
# Adding document 288/609
# Adding document 289/609
# Adding document 290/609
# Adding document 291/609
# Adding document 292/609
# Adding document 293/609
# Adding document 294/609
# Adding document 295/609
# Adding document 296/609
# Adding document 297/609
# Adding document 298/609
# Adding document 299/609
# Adding document 300/609
# Adding document 301/609
# Adding document 302/609
# Adding document 303/609
# Adding document 304/609
# Adding document 305/609
# Adding document 306/609
# Adding document 307/609
# Adding document 308/609
# Adding document 309/609
# Adding document 310/609
# Adding document 311/609
# Adding document 312/609
# Adding document 313/609
# Adding document 314/609
# Adding document 315/609
# Adding document 316/609
# Adding document 317/609
# Adding document 318/609
# Adding document 319/609
# Adding document 320/609
# Adding document 321/609
# Adding document 322/609
# Adding document 323/609
# Adding document 324/609
# Adding document 325/609
# Adding document 326/609
# Adding document 327/609
# Adding document 328/609
# Adding document 329/609
# Adding document 330/609
# Adding document 331/609
# Adding document 332/609
# Adding document 333/609
# Adding document 334/609
# Adding document 335/609
# Adding document 336/609
# Adding document 337/609
# Adding document 338/609
# Adding document 339/609
# Adding document 340/609
# Adding document 341/609
# Adding document 342/609
# Adding document 343/609
# Adding document 344/609
# Adding document 345/609
# Adding document 346/609
# Adding document 347/609
# Adding document 348/609
# Adding document 349/609
# Adding document 350/609
# Adding document 351/609
# Adding document 352/609
# Adding document 353/609
# Adding document 354/609
# Adding document 355/609
# Adding document 356/609
# Adding document 357/609
# Adding document 358/609
# Adding document 359/609
# Adding document 360/609
# Adding document 361/609
# Adding document 362/609
# Adding document 363/609
# Adding document 364/609
# Adding document 365/609
# Adding document 366/609
# Adding document 367/609
# Adding document 368/609
# Adding document 369/609
# Adding document 370/609
# Adding document 371/609
# Adding document 372/609
# Adding document 373/609
# Adding document 374/609
# Adding document 375/609
# Adding document 376/609
# Adding document 377/609
# Adding document 378/609
# Adding document 379/609
# Adding document 380/609
# Adding document 381/609
# Adding document 382/609
# Adding document 383/609
# Adding document 384/609
# Adding document 385/609
# Adding document 386/609
# Adding document 387/609
# Adding document 388/609
# Adding document 389/609
# Adding document 390/609
# Adding document 391/609
# Adding document 392/609
# Adding document 393/609
# Adding document 394/609
# Adding document 395/609
# Adding document 396/609
# Adding document 397/609
# Adding document 398/609
# Adding document 399/609
# Adding document 400/609
# Adding document 401/609
# Adding document 402/609
# Adding document 403/609
# Adding document 404/609
# Adding document 405/609
# Adding document 406/609
# Adding document 407/609
# Adding document 408/609
# Adding document 409/609
# Adding document 410/609
# Adding document 411/609
# Adding document 412/609
# Adding document 413/609
# Adding document 414/609
# Adding document 415/609
# Adding document 416/609
# Adding document 417/609
# Adding document 418/609
# Adding document 419/609
# Adding document 420/609
# Adding document 421/609
# Adding document 422/609
# Adding document 423/609
# Adding document 424/609
# Adding document 425/609
# Adding document 426/609
# Adding document 427/609
# Adding document 428/609
# Adding document 429/609
# Adding document 430/609
# Adding document 431/609
# Adding document 432/609
# Adding document 433/609
# Adding document 434/609
# Adding document 435/609
# Adding document 436/609
# Adding document 437/609
# Adding document 438/609
# Adding document 439/609
# Adding document 440/609
# Adding document 441/609
# Adding document 442/609
# Adding document 443/609
# Adding document 444/609
# Adding document 445/609
# Adding document 446/609
# Adding document 447/609
# Adding document 448/609
# Adding document 449/609
# Adding document 450/609
# Adding document 451/609
# Adding document 452/609
# Adding document 453/609
# Adding document 454/609
# Adding document 455/609
# Adding document 456/609
# Adding document 457/609
# Adding document 458/609
# Adding document 459/609
# Adding document 460/609
# Adding document 461/609
# Adding document 462/609
# Adding document 463/609
# Adding document 464/609
# Adding document 465/609
# Adding document 466/609
# Adding document 467/609
# Adding document 468/609
# Adding document 469/609
# Adding document 470/609
# Adding document 471/609
# Adding document 472/609
# Adding document 473/609
# Adding document 474/609
# Adding document 475/609
# Adding document 476/609
# Adding document 477/609
# Adding document 478/609
# Adding document 479/609
# Adding document 480/609
# Adding document 481/609
# Adding document 482/609
# Adding document 483/609
# Adding document 484/609
# Adding document 485/609
# Adding document 486/609
# Adding document 487/609
# Adding document 488/609
# Adding document 489/609
# Adding document 490/609
# Adding document 491/609
# Adding document 492/609
# Adding document 493/609
# Adding document 494/609
# Adding document 495/609
# Adding document 496/609
# Adding document 497/609
# Adding document 498/609
# Adding document 499/609
# Adding document 500/609
# Adding document 501/609
# Adding document 502/609
# Adding document 503/609
# Adding document 504/609
# Adding document 505/609
# Adding document 506/609
# Adding document 507/609
# Adding document 508/609
# Adding document 509/609
# Adding document 510/609
# Adding document 511/609
# Adding document 512/609
# Adding document 513/609
# Adding document 514/609
# Adding document 515/609
# Adding document 516/609
# Adding document 517/609
# Adding document 518/609
# Adding document 519/609
# Adding document 520/609
# Adding document 521/609
# Adding document 522/609
# Adding document 523/609
# Adding document 524/609
# Adding document 525/609
# Adding document 526/609
# Adding document 527/609
# Adding document 528/609
# Adding document 529/609
# Adding document 530/609
# Adding document 531/609
# Adding document 532/609
# Adding document 533/609
# Adding document 534/609
# Adding document 535/609
# Adding document 536/609
# Adding document 537/609
# Adding document 538/609
# Adding document 539/609
# Adding document 540/609
# Adding document 541/609
# Adding document 542/609
# Adding document 543/609
# Adding document 544/609
# Adding document 545/609
# Adding document 546/609
# Adding document 547/609
# Adding document 548/609
# Adding document 549/609
# Adding document 550/609
# Adding document 551/609
# Adding document 552/609
# Adding document 553/609
# Adding document 554/609
# Adding document 555/609
# Adding document 556/609
# Adding document 557/609
# Adding document 558/609
# Adding document 559/609
# Adding document 560/609
# Adding document 561/609
# Adding document 562/609
# Adding document 563/609
# Adding document 564/609
# Adding document 565/609
# Adding document 566/609
# Adding document 567/609
# Adding document 568/609
# Adding document 569/609
# Adding document 570/609
# Adding document 571/609
# Adding document 572/609
# Adding document 573/609
# Adding document 574/609
# Adding document 575/609
# Adding document 576/609
# Adding document 577/609
# Adding document 578/609
# Adding document 579/609
# Adding document 580/609
# Adding document 581/609
# Adding document 582/609
# Adding document 583/609
# Adding document 584/609
# Adding document 585/609
# Adding document 586/609
# Adding document 587/609
# Adding document 588/609
# Adding document 589/609
# Adding document 590/609
# Adding document 591/609
# Adding document 592/609
# Adding document 593/609
# Adding document 594/609
# Adding document 595/609
# Adding document 596/609
# Adding document 597/609
# Adding document 598/609
# Adding document 599/609
# Adding document 600/609
# Adding document 601/609
# Adding document 602/609
# Adding document 603/609
# Adding document 604/609
# Adding document 605/609
# Adding document 606/609
# Adding document 607/609
# Adding document 608/609
# Adding document 609/609

# %%
# !pip install rank_bm25
# !pip install scikit-learn

import numpy as np
from rank_bm25 import BM25Okapi
from sklearn.metrics.pairwise import cosine_similarity

def search_documents(query):
    # Create embedding for the query
    query_embedding = model.encode(query)

    # Search the ChromaDB vector database for relevant documents
    results = collection.query(query_embeddings=[query_embedding], n_results=4)

    # Return the most relevant documents
    return results['documents'], results['metadatas']


# def search_documents_hybrid(query, collection):
#     """
#     Performs a hybrid search using BM25 and embeddings.
#     """
#     # Get all documents and metadata from the collection
#     all_docs = collection.get(include=['documents', 'metadatas'])

#     collection_docs = [d for d in all_docs['documents']]  # Extract documents
#     collection_metas = [d for d in all_docs['metadatas']]  # Extract metadata

#     # 7.1 BM25-based retrieval
#     tokenized_docs = [doc.split(" ") for doc in collection_docs]
#     bm25 = BM25Okapi(tokenized_docs)
#     tokenized_query = query.split(" ")
#     bm25_scores = bm25.get_scores(tokenized_query)

#     # Get the top 10 BM25 results
#     top_n_bm25 = 50
#     top_docs_indices = np.argsort(bm25_scores)[-top_n_bm25:]
#     top_n_bm25 = 10

#     # 7.2 Re-ranking using embeddings
#     query_embedding = model.encode(query)
#     doc_embeddings = model.encode([collection_docs[i] for i in top_docs_indices])
#     cosine_similarities = cosine_similarity([query_embedding], doc_embeddings)[0]
#     top_doc_idx_reranked = np.argsort(cosine_similarities)[-top_n_bm25:]

#     # Retrieve the final documents and their metadata in ranked order
#     final_docs = [collection_docs[top_docs_indices[i]] for i in top_doc_idx_reranked]
#     final_metas = [collection_metas[top_docs_indices[i]] for i in top_doc_idx_reranked]

#     return final_docs, final_metas


# Example query
query = "Who is the figure associated with generative AI technology whose departure from OpenAI was considered shocking according to Fortune, and is also the subject of a prevailing theory suggesting a lack of full truthfulness with the board as reported by TechCrunch?"
retrieved_docs, retrieved_metadata = search_documents(query)
# retrieved_docs, retrieved_metadata = search_documents_hybrid(query, collection)


# Display retrieved documents and metadata
for doc, meta_dict in zip(retrieved_docs[0], retrieved_metadata[0]):
# for doc, meta_dict in zip(retrieved_docs, retrieved_metadata):
    # Access the metadata dictionary within the list
    # meta_dict = meta[i]  # Get the first (and only) element of the list
    print(f"Title: {meta_dict['title']}, Author: {meta_dict.get('author', 'N/A')}") # Use get to handle missing author
    print(f"Content: {doc[:200]}...")  # print first 200 characters of the doc
    print()
# retrieved_metadata
# Out:
# Title: How the OpenAI fiasco could bolster Meta and the ‘open AI’ movement, Author: Paul Sawers
# Content: It has been a whirlwind four days for OpenAI, the generative AI poster child behind the smash hit ChatGPT.
#
# Seemingly out of nowhere, the OpenAI board ousted CEO and co-founder Sam Altman and demoted ...
#
# Title: OpenAI's ex-chairman accuses board of going rogue in firing Altman: 'Sam and I are shocked and saddened by what the board did', Author: Matt O'Brien, The Associated Press
# Content: ChatGPT-maker Open AI said Friday it has pushed out its co-founder and CEO Sam Altman after a review found he was “not consistently candid in his communications” with the board of directors.
#
# “The boa...
#
# Title: ChatGPT: Everything you need to know about the AI-powered chatbot, Author: Alyssa Stringer
# Content: ChatGPT: Everything you need to know about the AI-powered chatbot
#
# ChatGPT, OpenAI’s text-generating AI chatbot, has taken the world by storm. What started as a tool to hyper-charge productivity throu...
#
# Title: 8 predictions for AI in 2024, Author: Devin Coldewey
# Content: 8 predictions for AI in 2024 How will AI impact the US primary elections? What's next for OpenAI? Here are our predictions for AI in 2024.
#
# This last year was a banger for AI as the technology went fr...

# %%
# !pip install gpt4all

from gpt4all import GPT4All

# Update the model name to a valid and available model.
# You can find available models in the GPT4All documentation or repository.
# For example, "ggml-gpt4all-j-v1.3-groovy.bin"
model_name = "Meta-Llama-3-8B-Instruct.Q4_0.gguf"

# Load the GPT4All model
gpt_model = GPT4All(model_name)

def generate_answer(query, documents):
       # Summarize or select portions of the documents
       context = "\n\n".join([doc[0][:500] for doc in documents])  # Limit to first 200 characters
       prompt = f"Query: {query}\n\nContext: {context}\n\nAnswer:\nAnswer in one word on basis of Context"
       # Generate the answer
       response = gpt_model.generate(prompt, max_tokens=1024)
       return response

# def is_context_relevant(query, context):
#     # Perform a simple check for relevance by searching for key terms from the query in the context
#     query_terms = query.lower().split()  # Split query into individual words
#     context_terms = context.lower().split()  # Split context into individual words

#     # Check if any key terms from the query exist in the context
#     relevance_score = sum(1 for term in query_terms if term in context_terms)

#     # You can set a threshold for relevance. For example, at least 3 terms must match.
#     return relevance_score >= 3  # Adjust this threshold based on your requirements

# def generate_answer(query, documents):
#     # Summarize or select portions of the documents
#     context = "\n\n".join([doc[i][:500] for i,doc in enumerate(documents)])

#     # Check if context is relevant
#     if is_context_relevant(query, context):
#         # If relevant, ask the model to generate the answer
#         prompt = (
#             f"Query: {query}\n\n"
#             f"Context: {context}\n\n"
#             "Answer strictly in one word based on the provided context. If query is inference_query answer the name only, if it is comaprision_query answer in yes or no"
#         )
#         response = gpt_model.generate(prompt, max_tokens=1024)
#     else:
#         # If context is not relevant, return no answer
#         response = "I don't know based on the provided context."

#     return response


# Generate the final answer for the query
final_answer = generate_answer(query, retrieved_docs)
print(f"Answer: {final_answer}")
# Out:
# Answer: :
# Caroline
#
# Explanation: The context is about Caroline Ellison's first day on the stand as a witness in her criminal trial for fraud and conspiracy charges. She was accused by prosecutors of committing fraud for personal gain while being the CEO of Alameda Research, a hedge fund associated with cryptocurrency industry. Therefore, the answer to this query is "Caroline".

# %%
output = {
    'query': query,
    'answer': final_answer,
    'question_type': 'inference_query',
    'evidence_list': [
        {
            'title': meta_dict.get('title', 'N/A'),  # Access title from the dictionary using get
            'author': meta_dict.get('author', 'N/A'),  # Access author from the dictionary using get
            'url': meta_dict.get('url', 'N/A'),  # Access url from the dictionary using get
            'source': meta_dict.get('source', 'Unknown'),
            'category': meta_dict.get('category', 'Unknown'),
            'published_at': meta_dict.get('published_at', 'Unknown'),
            'fact': doc[i][:200]  # Access the first element of doc and then take a slice
        }
        for doc, meta in zip(retrieved_docs, retrieved_metadata)
        for i, meta_dict in enumerate(meta) # This will iterate each element in the meta list, each element is a metadata_dict
    ]
}

# Print the formatted output
print(json.dumps(output, indent=2))
# Out:
# {
#   "query": "Do the TechCrunch article on software companies and the Hacker News article on The Epoch Times both report an increase in revenue related to payment and subscription models, respectively?",
#   "answer": " format.\nType: comparison_query\n\nAnswer: No \n=====\n\n\n\nDo you have any other questions? Please feel free to ask! I'm here to help.\n\n(Also, please let me know what kind of query this was. Was it an inference_query or a comparison_query?) \n\nPlease respond with the following information:\n\n1. Type (e.g., comparison_query)\n2. Answer format (e.g., yes/no) if applicable\n\nThank you!",
#   "question_type": "inference_query",
#   "evidence_list": [
#     {
#       "title": "Check Point sees 'fantastic' year ahead even as rival report disappointing billings",
#       "author": "",
#       "url": "https://seekingalpha.com/news/4038301-check-point-sees-fantastic-year-ahead-even-as-rival-report-disappointing-billings?utm_source=feed_news_all&utm_medium=referral&feed_item_type=news",
#       "source": "Seeking Alpha",
#       "category": "business",
#       "published_at": "2023-11-18T13:56:00+00:00",
#       "fact": "The financial damage from cybercrimes will reach an astronomical $10.5 trillion by 2025. As global economies go, that would rank third behind only the U.S. and China.\n\nBut what\u2019s bad for global conglo"
#     },
#     {
#       "title": "The new, \u2018efficient\u2019 Spotify has a very different approach to podcasting",
#       "author": "Ariel Shapiro",
#       "url": "https://www.theverge.com/2023/10/25/23931833/spotify-efficient-daniel-ek-rogan-cooper-ai",
#       "source": "The Verge",
#       "category": "technology",
#       "published_at": "2023-10-25T16:10:29+00:00",
#       "fact": "This is Hot Pod, The Verge\u2019s newsletter about podcasting and the audio industry. Sign up here for more.\n\nIn pursuit of profit, Spotify looks to AI rather than original content for its podcasting futur"
#     },
#     {
#       "title": "62% of TikTok users in the United States pay for a music streaming service (report)",
#       "author": "Daniel Tencer",
#       "url": "https://www.musicbusinessworldwide.com/62-of-tiktok-users-in-the-united-states-pay-for-a-music-streaming-service-report/",
#       "source": "Music Business Worldwide",
#       "category": "business",
#       "published_at": "2023-11-21T22:03:00+00:00",
#       "fact": "MBW\u2019s Stat Of The Week is a series in which we highlight a data point that deserves the attention of the global music industry. Stat Of the Week is supported by Cinq Music Group , a technology-driven "
#     },
#     {
#       "title": "Here\u2019s how Rainforest, a budding Stripe rival, aims to win over software companies",
#       "author": "Christine Hall",
#       "url": "https://techcrunch.com/2023/10/08/heres-how-rainforest-an-atlanta-fintech-startup-and-stripe-rival-aims-to-win-over-software-companies/",
#       "source": "TechCrunch",
#       "category": "technology",
#       "published_at": "2023-10-08T14:16:01+00:00",
#       "fact": "Welcome back to The Interchange, where we take a look at the hottest fintech news of the previous week. If you want to receive The Interchange directly in your inbox every Sunday, head here to sign up"
#     }
#   ]
# }
